# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd /content/drive/My Drive/Research Project
# Out:
# /content/drive/My Drive/Research Project

# %%
import pandas as pd
import numpy as np
import os
# import src
import matplotlib.pyplot as plt
import seaborn as sns

# %%
pip install -U mittens
# Out:
# Collecting mittens
#   Downloading https://files.pythonhosted.org/packages/ce/c0/6e4fce5b3cb88edde2e657bb4da9885c0aeac232981706beed7f43773b00/mittens-0.2-py3-none-any.whl
# Requirement already satisfied, skipping upgrade: numpy in /usr/local/lib/python3.6/dist-packages (from mittens) (1.18.5)
# Installing collected packages: mittens
# Successfully installed mittens-0.2

# %%
from numpy import asarray
from numpy import zeros

from sklearn.utils import shuffle
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score
from sklearn.model_selection import train_test_split, cross_val_score, KFold

from statistics import mean, stdev, median, mode

import nltk
from nltk.tokenize import word_tokenize
from sklearn.feature_extraction.text import CountVectorizer

from mittens import GloVe, Mittens
from hyperopt import fmin, tpe, hp

# %%
import tensorflow as tf

from tensorflow.keras import Sequential
from tensorflow.keras.models import load_model

from tensorflow.keras.layers import Embedding
from tensorflow.keras import layers

from tensorflow.keras.layers import Input
from tensorflow.keras.layers import Conv3D
from tensorflow.keras.layers import BatchNormalization
from tensorflow.keras.layers import LeakyReLU
from tensorflow.keras.layers import PReLU
from tensorflow.keras.layers import MaxPool3D, AveragePooling3D

from tensorflow.keras.layers import Dropout
from tensorflow.keras.layers import AveragePooling3D
from tensorflow.keras.layers import Dense
from tensorflow.keras.layers import Flatten

# %%
pip install autocorrect
# Out:
# Collecting autocorrect
#   Downloading https://files.pythonhosted.org/packages/a0/71/eb8c1f83439dfe6cbe1edb03be1f1110b242503b61950e7c292dd557c23e/autocorrect-2.2.2.tar.gz (621kB)
#      |████████████████████████████████| 624kB 13.4MB/s
# Building wheels for collected packages: autocorrect
#   Building wheel for autocorrect (setup.py) ... done
#   Created wheel for autocorrect: filename=autocorrect-2.2.2-cp36-none-any.whl size=621491 sha256=fe869893cc45760cfc7bc2ebc96d2e1460df7bf2d5160408a413f248fcc12a50
#   Stored in directory: /root/.cache/pip/wheels/b4/0b/7d/98268d64c8697425f712c897265394486542141bbe4de319d6
# Successfully built autocorrect
# Installing collected packages: autocorrect
# Successfully installed autocorrect-2.2.2

# %%
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# True

# %%
import tensorflow_addons as tfa
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.layers import Flatten, Dropout, MaxPool1D
from tensorflow.keras import optimizers
from tensorflow.keras.layers import Embedding, SimpleRNN, LSTM, GRU, Bidirectional
import tensorflow.keras.backend as K

# %% [markdown]
# ### Getting Data

# %%
# data_path = r'C:\Users\kalya\OneDrive - University of Illinois at Chicago\!UIC\!Semesters\3rd Sem\CS 583 Data Mining and Text Mining\Research Project\Data'

# %%
data_path = r'/content/drive/My Drive/Research Project/Data'

# %%
train_pr_df = pd.read_csv(os.path.join(data_path, 'Obama Training Data.csv'), usecols = [1,2]).dropna()
val_pr_df = pd.read_csv(os.path.join(data_path, 'Obama Validation Data.csv'), usecols = [1,2]).dropna()

# %%
train_pr_df.head()
# Out:
#                                             Doc Text Sentiment
# 0  obama need b remove dangerous white house czar...  Negative
# 1            sidenote obama profile sexy back debate  Positive
# 2        hillary take bullet obama n buck still fall  Negative
# 3  morgan freeman obama best commercial ever need...  Positive
# 4        bitch like obama bitch want food stamp lmao   Neutral

# %%
val_pr_df.head()
# Out:
#                                             Doc Text Sentiment
# 0  hell obama can not even take care one border p...  Negative
# 1     obama save auto industry enough say team obama  Positive
# 2    great obama hope take today sport section cheat  Negative
# 3          appreciate obama capitalisizes fact black  Negative
# 4  ann romney michelle obama dress second debate ...   Neutral

# %%
train1_pr_df = pd.read_csv(os.path.join(data_path, 'Obama Training1 Data.csv'), usecols = [1,2]).dropna()

# %%
train1_pr_df.head()
# Out:
#                                             Doc Text Sentiment
# 0  kirkpatrick wear baseball cap embroider obama ...   Neutral
# 1  obama debate cracker as cracker tonight tune t...  Positive
# 2  miss point afraid understand big picture dont ...   Neutral
# 3  raise democrat leave party year ago lifetime n...  Negative
# 4  obama camp can not afford low expectation toni...   Neutral

# %% [markdown]
# ## Building CNN Models

# %%
# int_sequences_input = layers.Input(shape=(None,), dtype="int64")
# embedded_sequences = embedding_layer(int_sequences_input)
# x = layers.Conv1D(128, 5, activation="relu")(embedded_sequences)
# x = layers.MaxPooling1D(5)(x)
# x = layers.Conv1D(128, 5, activation="relu")(x)
# x = layers.MaxPooling1D(5)(x)
# x = layers.Conv1D(128, 5, activation="relu")(x)
# x = layers.GlobalMaxPooling1D()(x)
# x = layers.Dense(128, activation="relu")(x)
# x = layers.Dropout(0.5)(x)
# preds = layers.Dense(len(class_names), activation="softmax")(x)
# model = keras.Model(int_sequences_input, preds)
# model.summary()

# %%
def one_hot(data):
    data = np.asarray(data)
    temp = np.zeros((len(data),3))
#     print(data[0])
    for i in range(len(temp)):
        if data[i] == 'Negative':
            temp[i][2] = 1 ## Negative sentiment third neuron
        elif data[i] == 'Neutral':
            temp[i][1] = 1 ## Neutral sentiment second neuron  
        else:
            temp[i][0] = 1 ## Positive sentiment first neuron 

    return temp

# %%
def pred(x):
    temp = []
    for i in x:
        m = np.argmax(i)
        if m == 0:
            temp.append('Positive')
        elif m == 1:
            temp.append('Neutral')
        else:
            temp.append('Negative')
    return temp

# %% [markdown]
# ## Building Glove Dictionary

# %%
embeddings = {}
with open(os.path.join(data_path,"glove.twitter.27B.200d.txt"), 'r', encoding="utf-8") as file:
    for line in file:
        values = line.split()
        word = values[0]
        vector = asarray(values[1:], dtype='float32')
        embeddings[word] = vector

# %% [markdown]
# ## Embedding Matrix Function

# %%
def emb_matrix(t,embeddings, we_dim):
    # creating a embedding matrix for the words in training data, which will be used as weight matrix for embedding layer
    vocab_size = len(t.word_index) + 1    
    embedding_matrix = zeros((vocab_size, we_dim))
    for word, i in t.word_index.items():
        embedding_vector = embeddings.get(word)
        if embedding_vector is not None:
            embedding_matrix[i] = embedding_vector
    return embedding_matrix, vocab_size

# %% [markdown]
# ## Fine tuning the word embeddings of 300 dimensions using mittens library

# %% [markdown]
# ## Used the code for finetuning from the following link:
# ### https://towardsdatascience.com/fine-tune-glove-embeddings-using-mittens-89b5f3fe4c39

# %%
def finetune(training): 
    training_tokens = [word_tokenize(i) for i in training]
    #training_tokens

    oov = [j for i in training_tokens for j in i if j not in embeddings.keys()]
    # print(len(oov))

    corp_vocab = list(set(oov))

    cv = CountVectorizer(ngram_range=(1,1), vocabulary=corp_vocab)
    trr =''
    for i in training_tokens:
        for j in i:
            trr+= j
            trr += ' '

    # print(trr)
    # print(z)
    X = cv.fit_transform([trr])
    Xc = (X.T * X)
    Xc.setdiag(0)
    coocc_ar = Xc.toarray()

    mittens_model = Mittens(n=200, max_iter=len(oov)+200,  display_progress = 0)

    new_embeddings = mittens_model.fit(
      coocc_ar,
      vocab=corp_vocab,
      initial_embedding_dict= embeddings)

    new_embeddings = dict(zip(corp_vocab, new_embeddings))
    return training_tokens, new_embeddings

# %%
# embeddings2= embeddings.copy()

# training_tokens, new_embeddings = finetune(train1_pr_df)
# embeddings2.update(new_embeddings)

# %%
# oov2 = [j for i in training_tokens for j in i if j not in embeddings2.keys()]
# print(len(oov2))

# %% [markdown]
# ## Using CNN

# %%
def model_cnn1(embedding_matrix, vocab_size, epochs,batch_size,max_length, learning_rate, we_dim):

    adam_optimizer = optimizers.Adam(learning_rate=learning_rate)

    embedding_layer = Embedding(vocab_size, we_dim, embeddings_initializer=tf.keras.initializers.Constant(embedding_matrix),trainable=False)
    int_sequences_input = layers.Input(shape=(None,), dtype="int64")
    embedded_sequences = embedding_layer(int_sequences_input)

    x = layers.Conv1D(64, 3)(embedded_sequences)
    x = BatchNormalization()(x)
    x = LeakyReLU()(x)
    x = layers.MaxPooling1D(2)(x)
    x = layers.Conv1D(128, 3)(x)
    x = BatchNormalization()(x)
    x = LeakyReLU()(x)
    x = layers.MaxPooling1D(2)(x)

    x = layers.Conv1D(256, 3)(x)
    x = BatchNormalization()(x)
    x = LeakyReLU()(x)
    x = layers.GlobalMaxPooling1D()(x)
    # x = layers.MaxPooling1D(2)(x)

    x = layers.Flatten()(x)
    x = layers.Dense(128, activation="tanh")(x)
    x = layers.Dropout(0.2)(x)
    x = layers.Dense(128, activation="tanh")(x)
    x = layers.Dropout(0.2)(x)
    preds = layers.Dense(3, activation="softmax")(x)

    model = tf.keras.Model(int_sequences_input, preds)
    # print(model.summary())
    # print(z)
    model.compile(optimizer=adam_optimizer, loss='categorical_crossentropy', metrics=['acc'])
    return model

# %%
def model_cnn2(embedding_matrix, vocab_size, epochs,batch_size,max_length, learning_rate, we_dim):

    adam_optimizer = optimizers.Adam(learning_rate=learning_rate)

    embedding_layer = Embedding(vocab_size, we_dim, embeddings_initializer=tf.keras.initializers.Constant(embedding_matrix),trainable=False)
    int_sequences_input = layers.Input(shape=(None,), dtype="int64")
    embedded_sequences = embedding_layer(int_sequences_input)

    x = layers.Conv1D(32, 3)(embedded_sequences)
    x = BatchNormalization()(x)
    x = LeakyReLU()(x)
    x = layers.MaxPooling1D(2)(x)
    x = layers.Conv1D(64, 3)(x)
    x = BatchNormalization()(x)
    x = LeakyReLU()(x)
    x = layers.GlobalMaxPooling1D()(x)

    x = layers.Flatten()(x)
    x = layers.Dense(128, activation="tanh")(x)
    x = layers.Dropout(0.2)(x)
    x = layers.Dense(128, activation="tanh")(x)
    x = layers.Dropout(0.2)(x)
    preds = layers.Dense(3, activation="softmax")(x)

    model = tf.keras.Model(int_sequences_input, preds)
    # print(model.summary())
    # print(z)
    model.compile(optimizer=adam_optimizer, loss='categorical_crossentropy', metrics=['acc'])
    return model

# %%
def model_cnn3(embedding_matrix, vocab_size, epochs,batch_size,max_length, learning_rate, we_dim):

    adam_optimizer = optimizers.Adam(learning_rate=learning_rate)

    embedding_layer = Embedding(vocab_size, we_dim, embeddings_initializer=tf.keras.initializers.Constant(embedding_matrix),trainable=False)
    int_sequences_input = layers.Input(shape=(None,), dtype="int64")
    embedded_sequences = embedding_layer(int_sequences_input)

    x = layers.Conv1D(64, 3)(embedded_sequences)
    x = BatchNormalization()(x)
    x = LeakyReLU()(x)
    x = layers.GlobalMaxPooling1D()(x)

    x = layers.Flatten()(x)
    x = layers.Dense(128, activation="tanh")(x)
    x = layers.Dropout(0.2)(x)
    x = layers.Dense(128, activation="tanh")(x)
    x = layers.Dropout(0.2)(x)
    preds = layers.Dense(3, activation="softmax")(x)

    model = tf.keras.Model(int_sequences_input, preds)
    # print(model.summary())
    # print(z)
    model.compile(optimizer=adam_optimizer, loss='categorical_crossentropy', metrics=['acc'])
    return model

# %%
# max_length = 31
# epochs = 2
# batch_size = 64
# learning_rate = 0.001
# we_dim = 200
# par_dict = {'max_length': max_length, 'batch_size': batch_size, 'learning_rate': learning_rate, 'epochs': epochs}
# print(par_dict)

# tokenise_tf = Tokenizer()
# tokenise_tf.fit_on_texts(romney_train_pr_df['Doc Text']) 

# encoded_train = tokenise_tf.texts_to_sequences(romney_train_pr_df['Doc Text'])
# training_padded = pad_sequences(encoded_train, maxlen=max_length, padding='post', truncating = 'pre')
# embedding_matrix, vocab_size = emb_matrix(tokenise_tf, embeddings, we_dim)

# encoded_validation = tokenise_tf.texts_to_sequences(romney_val_pr_df['Doc Text'])
# validation_padded = pad_sequences(encoded_validation, maxlen=max_length, padding='post', truncating = 'pre')

# try: 
#   model = model_cnn1(embedding_matrix, vocab_size, epochs,batch_size,max_length, learning_rate, we_dim)
#   history = model.fit(training_padded, one_hot(romney_train_pr_df['Sentiment']), epochs=epochs, verbose=0, batch_size=batch_size, shuffle =True)

# except:
#   try: 
#     model = model_cnn2(embedding_matrix, vocab_size, epochs,batch_size,max_length, learning_rate, we_dim)
#     history = model.fit(training_padded, one_hot(romney_train_pr_df['Sentiment']), epochs=epochs, verbose=0, batch_size=batch_size, shuffle =True)
#   except:

#     model = model_cnn3(embedding_matrix, vocab_size, epochs,batch_size,max_length, learning_rate, we_dim)
#     history = model.fit(training_padded, one_hot(romney_train_pr_df['Sentiment']), epochs=epochs, verbose=0, batch_size=batch_size, shuffle =True)


# y_pred_temp = model.predict(validation_padded)
# y_pred = pred(y_pred_temp)
# f1_temp = f1_score(romney_val_pr_df['Sentiment'], y_pred, average = None)

# f1_Positive = f1_temp[2]
# f1_Neutral = f1_temp[1]
# f1_Negative = f1_temp[0]

# accuracy = round(accuracy_score(romney_val_pr_df['Sentiment'], y_pred),3) 
# eval_score = round(mean([accuracy, f1_Positive, f1_Negative]),3)   
# eval_dict = {'accuracy': accuracy, 'f1_pos': f1_Positive, 'f1_neu': f1_Neutral, 'f1_neg': f1_Negative, 'eval_score': eval_score}
# print('\n')
# print(eval_dict)

# %%
def cross_valid_cnn(X,y,epochs,batch_size,max_length, learning_rate, we_dim):
    # print('dfd')
    f1_Positive  =[]
    f1_Neutral =[]
    f1_Negative =[]
    eval =[]
    acc =[]
    cv = KFold(n_splits=5,shuffle=True)
    for train_index, val_index in cv.split(X):
    #     print("Train Index: ", train_index, "\n")
    #     print("Test Index: ", test_index)
    #     print(X.iloc[train_index])
    #     print(f)

        X_train1, X_val, y_train1, y_val = X.iloc[train_index], X.iloc[val_index], y.iloc[train_index], y.iloc[val_index]
        tokenise_tf = Tokenizer()
        tokenise_tf.fit_on_texts(X_train1) 
    
        encoded_train = tokenise_tf.texts_to_sequences(X_train1)
        training_padded = pad_sequences(encoded_train, maxlen=max_length, padding='post', truncating = 'pre')
        # print(X_train1['Doc Text'])

        embeddings2= embeddings.copy()

        training_tokens, new_embeddings = finetune(X_train1)
        embeddings2.update(new_embeddings)

        embedding_matrix, vocab_size = emb_matrix(tokenise_tf, embeddings2, we_dim)

        encoded_validation = tokenise_tf.texts_to_sequences(X_val)
        validation_padded = pad_sequences(encoded_validation, maxlen=max_length, padding='post', truncating = 'pre')
        # print('dfd')
        try: 
            model = model_cnn1(embedding_matrix, vocab_size, epochs,batch_size,max_length, learning_rate, we_dim)
            history = model.fit(training_padded, one_hot(y_train1), epochs=epochs, verbose=0, batch_size=batch_size, shuffle =True)

        except:
            try:            
                model = model_cnn2(embedding_matrix, vocab_size, epochs,batch_size,max_length, learning_rate, we_dim)
                history = model.fit(training_padded, one_hot(y_train1), epochs=epochs, verbose=0, batch_size=batch_size, shuffle =True)
            except:

                model = model_cnn3(embedding_matrix, vocab_size, epochs,batch_size,max_length, learning_rate, we_dim)
                history = model.fit(training_padded, one_hot(y_train1), epochs=epochs, verbose=0, batch_size=batch_size, shuffle =True)
        y_pred_temp = model.predict(validation_padded)
        y_pred = pred(y_pred_temp)
        f1_temp = f1_score(y_val, y_pred, average = None)

        f1_Positive.append(f1_temp[2])
        f1_Neutral.append(f1_temp[1])
        f1_Negative.append(f1_temp[0])

        accuracy = round(accuracy_score(y_val, y_pred),3)
        acc.append(accuracy)
        eval_score = round(mean([0.4*accuracy, 1.6*f1_temp[2]]),3)
        eval.append(eval_score)
        # print(eval_score)

    return round(mean(acc),3), round(mean(f1_Positive),3), round(mean(f1_Neutral),3), round(mean(f1_Negative),3), round(mean(eval),3)

# %%
# accuracy, f1_Positive, f1_Neutral, f1_Negative, eval_score = cross_valid_cnn(train1_pr_df['Doc Text'],train1_pr_df['Sentiment'], 2,32,20, 0.001, 200)

# %%
# print(dfaddf)

# %%
def objective_func_CNN_CV(args):
    max_length = args['max_length']
    batch_size = args['batch_size']
    learning_rate = args['learning_rate']
    epochs = args['epochs']

    par_dict = {'max_length': max_length, 'batch_size': batch_size, 'learning_rate': learning_rate, 'epochs': epochs}
    print(par_dict)

    accuracy, f1_Positive, f1_Neutral, f1_Negative, eval_score = cross_valid_cnn(train1_pr_df['Doc Text'],train1_pr_df['Sentiment'], epochs,batch_size,max_length, learning_rate, we_dim)  
    eval_dict = {'accuracy': accuracy, 'f1_pos': f1_Positive, 'f1_neu': f1_Neutral, 'f1_neg': f1_Negative, 'eval_score': eval_score}
    print('\n')
    print(eval_dict)

    return -(eval_score)

space = {'max_length': hp.choice('max_length',range(5,65,5)),  
        'batch_size': hp.choice('batch_size', [16, 32, 64]),
         'epochs': hp.choice('epochs',range(5,30,3)), 
         'learning_rate': hp.uniform('learning_rate', 0,0.01)
        }                  
                                    
we_dim = 200                               
best_CNN_CV = fmin(objective_func_CNN_CV, space, algo=tpe.suggest, max_evals=15)
print(best_CNN_CV)
# Out:
# {'max_length': 40, 'batch_size': 16, 'learning_rate': 0.006245609862137057, 'epochs': 11}
#   0%|          | 0/15 [00:00<?, ?it/s, best loss: ?]WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/training/adagrad.py:77: calling Constant.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/keras/engine/training_v1.py:2070: Model.state_updates (from tensorflow.python.keras.engine.training) is deprecated and will be removed in a future version.
# Instructions for updating:
# This property should not be used in TensorFlow 2.0, as updates are applied automatically.
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/client/session.py:1751: UserWarning: An interactive session is already active. This can cause out-of-memory errors in some cases. You must explicitly call `InteractiveSession.close()` to release resources held by the other session(s).
#   warnings.warn('An interactive session is already active. This can '
# {'accuracy': 0.518, 'f1_pos': 0.567, 'f1_neu': 0.462, 'f1_neg': 0.442, 'eval_score': 0.557}
# {'max_length': 10, 'batch_size': 16, 'learning_rate': 0.0017893266833287937, 'epochs': 14}
# {'accuracy': 0.517, 'f1_pos': 0.525, 'f1_neu': 0.468, 'f1_neg': 0.55, 'eval_score': 0.523}
# {'max_length': 25, 'batch_size': 64, 'learning_rate': 0.0029634790600181027, 'epochs': 14}
# {'accuracy': 0.53, 'f1_pos': 0.547, 'f1_neu': 0.466, 'f1_neg': 0.564, 'eval_score': 0.544}
# {'max_length': 10, 'batch_size': 64, 'learning_rate': 0.0046649660681123886, 'epochs': 26}
# {'accuracy': 0.507, 'f1_pos': 0.524, 'f1_neu': 0.485, 'f1_neg': 0.504, 'eval_score': 0.52}
# {'max_length': 55, 'batch_size': 32, 'learning_rate': 0.008226132461888365, 'epochs': 26}
# {'accuracy': 0.548, 'f1_pos': 0.544, 'f1_neu': 0.505, 'f1_neg': 0.583, 'eval_score': 0.545}
# {'max_length': 20, 'batch_size': 32, 'learning_rate': 0.005868904781720208, 'epochs': 5}
# {'accuracy': 0.553, 'f1_pos': 0.551, 'f1_neu': 0.513, 'f1_neg': 0.587, 'eval_score': 0.551}
# {'max_length': 40, 'batch_size': 16, 'learning_rate': 0.007133826755288013, 'epochs': 20}
# {'accuracy': 0.531, 'f1_pos': 0.551, 'f1_neu': 0.473, 'f1_neg': 0.542, 'eval_score': 0.547}
# {'max_length': 10, 'batch_size': 16, 'learning_rate': 0.0032042530185268994, 'epochs': 5}
# {'accuracy': 0.54, 'f1_pos': 0.54, 'f1_neu': 0.478, 'f1_neg': 0.587, 'eval_score': 0.54}
# {'max_length': 10, 'batch_size': 32, 'learning_rate': 0.0012278001199732024, 'epochs': 20}
# {'accuracy': 0.509, 'f1_pos': 0.51, 'f1_neu': 0.511, 'f1_neg': 0.497, 'eval_score': 0.51}
# {'max_length': 5, 'batch_size': 64, 'learning_rate': 0.004786960017442289, 'epochs': 5}
# {'accuracy': 0.493, 'f1_pos': 0.502, 'f1_neu': 0.408, 'f1_neg': 0.534, 'eval_score': 0.501}
# {'max_length': 55, 'batch_size': 32, 'learning_rate': 0.0045332449775266495, 'epochs': 23}
# {'accuracy': 0.536, 'f1_pos': 0.562, 'f1_neu': 0.493, 'f1_neg': 0.545, 'eval_score': 0.557}
# {'max_length': 10, 'batch_size': 16, 'learning_rate': 0.009616327837957654, 'epochs': 5}
# {'accuracy': 0.518, 'f1_pos': 0.545, 'f1_neu': 0.36, 'f1_neg': 0.592, 'eval_score': 0.539}
# {'max_length': 45, 'batch_size': 64, 'learning_rate': 0.007299653532761717, 'epochs': 17}
# {'accuracy': 0.54, 'f1_pos': 0.553, 'f1_neu': 0.512, 'f1_neg': 0.545, 'eval_score': 0.55}
# {'max_length': 5, 'batch_size': 16, 'learning_rate': 0.006526805574511838, 'epochs': 20}
# {'accuracy': 0.489, 'f1_pos': 0.479, 'f1_neu': 0.47, 'f1_neg': 0.502, 'eval_score': 0.481}
# {'max_length': 10, 'batch_size': 64, 'learning_rate': 0.005048088710667831, 'epochs': 29}
# {'accuracy': 0.514, 'f1_pos': 0.512, 'f1_neu': 0.464, 'f1_neg': 0.557, 'eval_score': 0.513}
# 100%|██████████| 15/15 [35:07<00:00, 140.49s/it, best loss: -0.557]
# {'batch_size': 0, 'epochs': 2, 'learning_rate': 0.006245609862137057, 'max_length': 7}

# %%
{'max_length': 30, 'batch_size': 32, 'learning_rate': 0.002545155034565767, 'epochs': 24}
{'accuracy': 0.537, 'f1_pos': 0.565, 'f1_neu': 0.437, 'f1_neg': 0.589, 'eval_score': 0.56}
# Out:
# {'accuracy': 0.537,
#  'eval_score': 0.56,
#  'f1_neg': 0.589,
#  'f1_neu': 0.437,
#  'f1_pos': 0.565}

# %%
print(dasfad)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-34-680d4d84f232> in <module>()
# ----> 1 print(dasfad)
#
# NameError: name 'dasfad' is not defined

# %%
def objective_func_CNN(args):
    max_length = args['max_length']
    batch_size = args['batch_size']
    learning_rate = args['learning_rate']
    epochs = args['epochs']

    par_dict = {'max_length': max_length, 'batch_size': batch_size, 'learning_rate': learning_rate, 'epochs': epochs}
    print(par_dict)

    tokenise_tf = Tokenizer()
    tokenise_tf.fit_on_texts(obama_train_pr_df['Doc Text']) 

    encoded_train = tokenise_tf.texts_to_sequences(obama_train_pr_df['Doc Text'])
    training_padded = pad_sequences(encoded_train, maxlen=max_length, padding='post', truncating = 'pre')
    embedding_matrix, vocab_size = emb_matrix(tokenise_tf, embeddings, we_dim)

    encoded_validation = tokenise_tf.texts_to_sequences(obama_val_pr_df['Doc Text'])
    validation_padded = pad_sequences(encoded_validation, maxlen=max_length, padding='post', truncating = 'pre')

    try: 
        model = model_cnn1(embedding_matrix, vocab_size, epochs,batch_size,max_length, learning_rate, we_dim)
        history = model.fit(training_padded, one_hot(obama_train_pr_df['Sentiment']), epochs=epochs, verbose=0, batch_size=batch_size, shuffle =True)

    except:
        try:            
            model = model_cnn2(embedding_matrix, vocab_size, epochs,batch_size,max_length, learning_rate, we_dim)
            history = model.fit(training_padded, one_hot(obama_train_pr_df['Sentiment']), epochs=epochs, verbose=0, batch_size=batch_size, shuffle =True)
        except:

            model = model_cnn3(embedding_matrix, vocab_size, epochs,batch_size,max_length, learning_rate, we_dim)
            history = model.fit(training_padded, one_hot(obama_train_pr_df['Sentiment']), epochs=epochs, verbose=0, batch_size=batch_size, shuffle =True)


    y_pred_temp = model.predict(validation_padded)
    y_pred = pred(y_pred_temp)
    f1_temp = np.round(f1_score(obama_val_pr_df['Sentiment'], y_pred, average = None),3)

    f1_Positive = f1_temp[2]
    f1_Neutral = f1_temp[1]
    f1_Negative = f1_temp[0]

    accuracy = round(accuracy_score(obama_val_pr_df['Sentiment'], y_pred),3) 
    eval_score = round(mean([0.4*accuracy, 1.6*f1_temp[0]]),3)  
    eval_dict = {'accuracy': accuracy, 'f1_pos': f1_Positive, 'f1_neu': f1_Neutral, 'f1_neg': f1_Negative, 'eval_score': eval_score}
    print('\n')
    print(eval_dict)

    return -(eval_score)

space = {'max_length': hp.choice('max_length',range(4,60)),  
        'batch_size': hp.choice('batch_size', [32, 64, 128]),
         'epochs': hp.choice('epochs',range(5,30)), 
         'learning_rate': hp.uniform('learning_rate', 0,0.01)
        }                  
                                    
we_dim = 200                               
best_CNN = fmin(objective_func_CNN, space, algo=tpe.suggest, max_evals=20)
print(best_CNN)

# %%
{'max_length': 31, 'batch_size': 128, 'learning_rate': 0.00043843544096825674, 'epochs': 7}
{'accuracy': 0.547, 'f1_pos': 0.604, 'f1_neu': 0.403, 'f1_neg': 0.595, 'eval_score': 0.582}

# %%
# max_length = 30
# epochs = 20
# batch_size = 64
# learning_rate = 0.001
# we_dim = 200

# accuracy, f1_Positive, f1_Neutral, f1_Negative= cross_valid_cnn(obama_train_pr_df['Doc Text'],obama_train_pr_df['Sentiment'], epochs,batch_size,max_length, learning_rate, we_dim)
# f1 = round(mean([accuracy, f1_Positive, f1_Negative]),3)    
# eval_dict = {'accuracy': accuracy, 'f1_pos': f1_Positive, 'f1_neu': f1_Neutral, 'f1_neg': f1_Negative, 'f1_eval': f1}
# print('\n')
# print(eval_dict)

# %%
# def objective_func_CNN_CV(args):
#     max_length = args['max_length']
#     batch_size = args['batch_size']
#     learning_rate = args['learning_rate']
#     epochs = args['epochs']

#     par_dict = {'max_length': max_length, 'batch_size': batch_size, 'learning_rate': learning_rate, 'epochs': epochs}
#     print(par_dict)

#     accuracy, f1_Positive, f1_Neutral, f1_Negative= cross_valid_cnn(obama_train_pr_df['Doc Text'],obama_train_pr_df['Sentiment'], epochs,batch_size,max_length, learning_rate, we_dim)
#     f1 = round(mean([accuracy, f1_Positive, f1_Negative]),3)    
#     eval_dict = {'accuracy': accuracy, 'f1_pos': f1_Positive, 'f1_neu': f1_Neutral, 'f1_neg': f1_Negative, 'f1_eval': f1}
#     print('\n')
#     print(eval_dict)

#     return -(f1)

# space = {'max_length': hp.choice('max_length',range(4,60)),  
#         'batch_size': hp.choice('batch_size', [32, 64, 128]),
#          'epochs': hp.choice('epochs',range(5,30)), 
#          'learning_rate': hp.uniform('learning_rate', 0,0.01)
#         }                  
                                    
# we_dim = 200                               
# best_CNN_CV = fmin(objective_func_CNN_CV, space, algo=tpe.suggest, max_evals=20)
# print(best_CNN_CV)

# %% [markdown]
# ## Custom F1 value

# %%
def f1_value(y_true, y_pred): #taken from old keras source code
    true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
    possible_positives = K.sum(K.round(K.clip(y_true, 0, 1)))
    predicted_positives = K.sum(K.round(K.clip(y_pred, 0, 1)))
    precision = true_positives / (predicted_positives + K.epsilon())
    recall = true_positives / (possible_positives + K.epsilon())
    f1_val = 2*(precision*recall)/(precision+recall+K.epsilon())
    return f1_val
