#   Found existing installation: ipykernel 4.10.1
#     Uninstalling ipykernel-4.10.1:
#       Successfully uninstalled ipykernel-4.10.1
#   Found existing installation: tqdm 4.41.1
#     Uninstalling tqdm-4.41.1:
#       Successfully uninstalled tqdm-4.41.1
# Successfully installed GitPython-3.1.11 base58-2.0.1 blinker-1.4 boto3-1.16.22 botocore-1.19.22 configparser-5.0.1 docker-pycreds-0.4.0 enum-compat-0.0.3 gitdb-4.0.5 ipykernel-5.3.4 jmespath-0.10.0 pathtools-0.1.2 pydeck-0.5.0 s3transfer-0.3.3 sentry-sdk-0.19.4 seqeval-1.2.2 shortuuid-1.0.1 simpletransformers-0.49.2 smmap-3.0.4 streamlit-0.71.0 subprocess32-3.5.4 tensorboardx-2.1 tqdm-4.52.0 validators-0.18.1 wandb-0.10.11 watchdog-0.10.3

# %%
# pip install transformers

# %%
import pandas as pd
import numpy as np
import os
# import src
import matplotlib.pyplot as plt
import seaborn as sns

# %%
pip install -U mittens
# Out:
# Collecting mittens
#   Downloading https://files.pythonhosted.org/packages/ce/c0/6e4fce5b3cb88edde2e657bb4da9885c0aeac232981706beed7f43773b00/mittens-0.2-py3-none-any.whl
# Requirement already satisfied, skipping upgrade: numpy in /usr/local/lib/python3.6/dist-packages (from mittens) (1.18.5)
# Installing collected packages: mittens
# Successfully installed mittens-0.2

# %%
from numpy import asarray
from numpy import zeros

from sklearn.utils import shuffle
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score
from sklearn.model_selection import train_test_split, cross_val_score, KFold

from statistics import mean, stdev, median, mode

from nltk.tokenize import word_tokenize
from sklearn.feature_extraction.text import CountVectorizer

from mittens import GloVe, Mittens
from hyperopt import fmin, tpe, hp

# %%
import tensorflow as tf

from tensorflow.keras import Sequential
from tensorflow.keras.models import load_model

from tensorflow.keras.layers import Embedding
from tensorflow.keras import layers

from tensorflow.keras.layers import Input
from tensorflow.keras.layers import Conv3D
from tensorflow.keras.layers import BatchNormalization
from tensorflow.keras.layers import LeakyReLU
from tensorflow.keras.layers import PReLU
from tensorflow.keras.layers import MaxPool3D, AveragePooling3D

from tensorflow.keras.layers import Dropout
from tensorflow.keras.layers import AveragePooling3D
from tensorflow.keras.layers import Dense
from tensorflow.keras.layers import Flatten

# %%
from hyperopt import fmin, tpe, hp

# %%
# pip install autocorrect

# %%
# nltk.download('punkt')

# %%
import tensorflow_addons as tfa
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.layers import Flatten, Dropout, MaxPool1D
from tensorflow.keras import optimizers
from tensorflow.keras.layers import Embedding, SimpleRNN, LSTM, GRU, Bidirectional
import tensorflow.keras.backend as K

# %%
from simpletransformers.classification import ClassificationModel, ClassificationArgs

# %% [markdown]
# ### Getting Data

# %%
# data_path = r'C:\Users\kalya\OneDrive - University of Illinois at Chicago\!UIC\!Semesters\3rd Sem\CS 583 Data Mining and Text Mining\Research Project\Data'

# %%
data_path = r'/content/drive/My Drive/Research Project/Data'

# %%
train_pr_df = pd.read_csv(os.path.join(data_path, 'Romney Training Data.csv'), usecols = [1,2], names= ['text', 'labels'], header  = 0).dropna()
train_pr_df['labels'] = train_pr_df['labels'].apply(lambda x: 0 if x == 'Positive' else (2 if x == 'Negative' else 1))
val_pr_df = pd.read_csv(os.path.join(data_path, 'Romney Validation Data.csv'), usecols = [1,2], names= ['text', 'labels'], header  = 0).dropna()
val_pr_df['labels'] = val_pr_df['labels'].apply(lambda x: 0 if x == 'Positive' else (2 if x == 'Negative' else 1))

# %%
train_pr_df.head()
# Out:
#                                                 text  labels
# 0  believe romney able work w bipartisim gov brin...       0
# 1  ask romney past decade tax end obama debate pr...       0
# 2                          conclusion romney get own       0
# 3  register democrat nothing give reason change v...       0
# 4    aunt buy theiphone tell need vote romne shecray       1

# %%
val_pr_df.head()
# Out:
#                                                 text  labels
# 0                          vote romney waystogetshot       1
# 1                        waystogetshot voting romney       2
# 2               romney go stand china afraid go view       1
# 3        swing state poll woman push romney lead via       1
# 4  least job come back romney nba team outsource ...       2

# %%
train1_pr_df = pd.read_csv(os.path.join(data_path, 'Romney Training1 Data.csv'), usecols = [1,2],names= ['text', 'labels'], header  = 0).dropna()
train1_pr_df['labels'] = train1_pr_df['labels'].apply(lambda x: 0 if x == 'Positive' else (2 if x == 'Negative' else 1))

# %%
def evaluation(labels, preds):

  f1_temp = np.round(f1_score(labels, preds, average=None),3)

  f1_Positive = f1_temp[0]
  f1_Neutral = f1_temp[1]
  f1_Negative = f1_temp[2]
  accuracy = round(accuracy_score(labels, preds),3) 
  eval_score = round(mean([accuracy, f1_Positive, f1_Negative]),3) 
  return eval_score

# %%
train1_pr_df.head()
# Out:
#                                                 text  labels
# 0  insidious mitt romney bain help philip morris ...       2
# 1                     mean like romney cheat primary       2
# 2          mitt romney still believe black president       2
# 3  romney tax plan deserve nd look secret one dif...       2
# 4        hope romney debate prepped people last time       0

# %% [markdown]
# ## Building Transformer Models

# %%
# max_length = 66
# batch_size = 32

# par_dict = {'max_length': max_length, 'batch_size': batch_size}
# print(par_dict)
# model_args = ClassificationArgs(num_train_epochs=2, train_batch_size = batch_size, overwrite_output_dir=True, max_seq_length = max_length)
# model = ClassificationModel(model_type='roberta', model_name='roberta-base', use_cuda=True, num_labels=3, args=model_args)
# model.train_model(train_pr_df)

# y_pred = model.predict(val_pr_df['text'])[0]


# f1_temp = np.round(f1_score(val_pr_df['labels'], y_pred, average = None),3)
# recall = np.round(recall_score(val_pr_df['labels'], y_pred, average = None),3)
# precision = np.round(precision_score(val_pr_df['labels'], y_pred, average = None),3)

# f1_Positive = f1_temp[0]
# f1_Neutral = f1_temp[1]
# f1_Negative = f1_temp[2]

# accuracy = round(accuracy_score(val_pr_df['labels'], y_pred),3) 
# eval_score = round(mean([0.4*accuracy, 1.6*f1_Positive]),3)   
# eval_dict = {'accuracy': accuracy, 'f1_pos': f1_Positive, 'f1_neu': f1_Neutral, 'f1_neg': f1_Negative, 'eval_score': eval_score}
# print('\n')
# print(eval_dict)
# print("f1" + str(f1_temp))
# print('recall' + str(recall))
# print('Precision' + str(precision))

# %%
# print(dgaszdf)

# %%
# model_args = ClassificationArgs(num_train_epochs=1, train_batch_size = 64, overwrite_output_dir=True, max_seq_length = 30, learning_rate= 0.0001)
# model = ClassificationModel(model_type='xlmroberta', model_name='xlm-roberta-large', use_cuda=True, num_labels=3, args=model_args)
# model.train_model(train_pr_df)

# y_pred = model.predict(val_pr_df['text'])[0]
# f1_temp = np.round(f1_score(val_pr_df['labels'], y_pred, average = None),3)

# f1_Positive = f1_temp[0]
# f1_Neutral = f1_temp[1]
# f1_Negative = f1_temp[2]

# accuracy = round(accuracy_score(val_pr_df['labels'], y_pred),3) 
# eval_score = round(mean([accuracy, f1_Positive, f1_Negative]),3)   
# eval_dict = {'accuracy': accuracy, 'f1_pos': f1_Positive, 'f1_neu': f1_Neutral, 'f1_neg': f1_Negative, 'eval_score': eval_score}
# print('\n')
# print(eval_dict)

# %%
# print(sdfasdf)

# %%
# model_args = ClassificationArgs(num_train_epochs=1, train_batch_size = 64, overwrite_output_dir=True, max_seq_length = 30, learning_rate= 0.0001)
# model = ClassificationModel(model_type='xlnet', model_name='xlnet-large-cased', use_cuda=True, num_labels=3, args=model_args)
# model.train_model(train_pr_df)

# y_pred = model.predict(val_pr_df['text'])[0]
# f1_temp = np.round(f1_score(val_pr_df['labels'], y_pred, average = None),3)

# f1_Positive = f1_temp[0]
# f1_Neutral = f1_temp[1]
# f1_Negative = f1_temp[2]

# accuracy = round(accuracy_score(val_pr_df['labels'], y_pred),3) 
# eval_score = round(mean([accuracy, f1_Positive, f1_Negative]),3)   
# eval_dict = {'accuracy': accuracy, 'f1_pos': f1_Positive, 'f1_neu': f1_Neutral, 'f1_neg': f1_Negative, 'eval_score': eval_score}
# print('\n')
# print(eval_dict)

# %%
# model_args = ClassificationArgs(num_train_epochs=2, train_batch_size = 64, overwrite_output_dir=True, max_seq_length = 30, learning_rate= 0.0001)
# model = ClassificationModel(model_type='roberta', model_name='roberta-base', use_cuda=True, num_labels=3, args=model_args)
# model.train_model(train_pr_df)

# y_pred = model.predict(val_pr_df['text'])[0]
# f1_temp = np.round(f1_score(val_pr_df['labels'], y_pred, average = None),3)

# f1_Positive = f1_temp[0]
# f1_Neutral = f1_temp[1]
# f1_Negative = f1_temp[2]

# accuracy = round(accuracy_score(val_pr_df['labels'], y_pred),3) 
# eval_score = round(mean([accuracy, f1_Positive, f1_Negative]),3)   
# eval_dict = {'accuracy': accuracy, 'f1_pos': f1_Positive, 'f1_neu': f1_Neutral, 'f1_neg': f1_Negative, 'eval_score': eval_score}
# print('\n')
# print(eval_dict)

# %%
{'accuracy': 0.608, 'f1_pos': 0.565, 'f1_neu': 0.516, 'f1_neg': 0.694, 'eval_score': 0.622}
# Out:
# {'accuracy': 0.608,
#  'eval_score': 0.622,
#  'f1_neg': 0.694,
#  'f1_neu': 0.516,
#  'f1_pos': 0.565}

# %%
# model_args = ClassificationArgs(num_train_epochs=3, train_batch_size = 64, overwrite_output_dir=True, max_seq_length = 30, learning_rate= 0.00001)
# model = ClassificationModel(model_type='roberta', model_name='roberta-base', use_cuda=True, num_labels=3, args=model_args)
# model.train_model(train_pr_df)

# y_pred = model.predict(val_pr_df['text'])[0]
# f1_temp = np.round(f1_score(val_pr_df['labels'], y_pred, average = None),3)

# f1_Positive = f1_temp[0]
# f1_Neutral = f1_temp[1]
# f1_Negative = f1_temp[2]

# accuracy = round(accuracy_score(val_pr_df['labels'], y_pred),3) 
# eval_score = round(mean([accuracy, f1_Positive, f1_Negative]),3)   
# eval_dict = {'accuracy': accuracy, 'f1_pos': f1_Positive, 'f1_neu': f1_Neutral, 'f1_neg': f1_Negative, 'eval_score': eval_score}
# print('\n')
# print(eval_dict)

# %%
def objective_func_CNN(args):
    max_length = args['max_length']
    batch_size = args['batch_size']
    # learning_rate = args['learning_rate']
    # epochs = args['epochs']

    par_dict = {'max_length': max_length, 'batch_size': batch_size}
    print(par_dict)
    model_args = ClassificationArgs(num_train_epochs=2, train_batch_size = batch_size, overwrite_output_dir=True, max_seq_length = max_length)
    model = ClassificationModel(model_type='roberta', model_name='cardiffnlp/twitter-roberta-base-sentiment', use_cuda=True, num_labels=3, args=model_args)
    model.train_model(train_pr_df)

    y_pred = model.predict(val_pr_df['text'])[0]
    f1_temp = np.round(f1_score(val_pr_df['labels'], y_pred, average = None),3)

    f1_Positive = f1_temp[0]
    f1_Neutral = f1_temp[1]
    f1_Negative = f1_temp[2]

    accuracy = round(accuracy_score(val_pr_df['labels'], y_pred),3) 
    eval_score = round(mean([0.4*accuracy, 1.6*f1_Positive]),3)   
    eval_dict = {'accuracy': accuracy, 'f1_pos': f1_Positive, 'f1_neu': f1_Neutral, 'f1_neg': f1_Negative, 'eval_score': eval_score}
    print('\n')
    print(eval_dict)

    return -(eval_score)

space = {'max_length': hp.choice('max_length',range(5,60)),  
        'batch_size': hp.choice('batch_size', [16, 32, 64])
        #  'epochs': hp.choice('epochs',range(1,3)) 
        #  'learning_rate': hp.uniform('learning_rate', 0,0.0005)
        }                  
                                                              
best_T = fmin(objective_func_CNN, space, algo=tpe.suggest, max_evals=20)
print(best_T)
# Out:
# {'max_length': 37, 'batch_size': 16}
#   0%|          | 0/20 [00:00<?, ?it/s, best loss: ?]
# HBox(children=(HTML(value='Downloading'), FloatProgress(value=0.0, max=747.0), HTML(value='')))
# HBox(children=(HTML(value='Downloading'), FloatProgress(value=0.0, max=498679497.0), HTML(value='')))
# Some weights of RobertaForSequenceClassification were not initialized from the model checkpoint at cardiffnlp/twitter-roberta-base-sentiment and are newly initialized: ['roberta.pooler.dense.weight', 'roberta.pooler.dense.bias']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# HBox(children=(HTML(value='Downloading'), FloatProgress(value=0.0, max=898822.0), HTML(value='')))
# HBox(children=(HTML(value='Downloading'), FloatProgress(value=0.0, max=456318.0), HTML(value='')))
# HBox(children=(HTML(value='Downloading'), FloatProgress(value=0.0, max=150.0), HTML(value='')))
# HBox(children=(HTML(value=''), FloatProgress(value=0.0, max=4517.0), HTML(value='')))
# HBox(children=(HTML(value='Epoch'), FloatProgress(value=0.0, max=2.0), HTML(value='')))
# HBox(children=(HTML(value='Running Epoch 0 of 2'), FloatProgress(value=0.0, max=283.0), HTML(value='')))
# /usr/local/lib/python3.6/dist-packages/torch/optim/lr_scheduler.py:136: UserWarning: Detected call of `lr_scheduler.step()` before `optimizer.step()`. In PyTorch 1.1.0 and later, you should call them in the opposite order: `optimizer.step()` before `lr_scheduler.step()`.  Failure to do this will result in PyTorch skipping the first value of the learning rate schedule. See more details at https://pytorch.org/docs/stable/optim.html#how-to-adjust-learning-rate
#   "https://pytorch.org/docs/stable/optim.html#how-to-adjust-learning-rate", UserWarning)
#
# /usr/local/lib/python3.6/dist-packages/torch/optim/lr_scheduler.py:216: UserWarning: Please also save or load the state of the optimizer when saving or loading the scheduler.
#   warnings.warn(SAVE_STATE_WARNING, UserWarning)
# HBox(children=(HTML(value='Running Epoch 1 of 2'), FloatProgress(value=0.0, max=283.0), HTML(value='')))
# HBox(children=(HTML(value=''), FloatProgress(value=0.0, max=1130.0), HTML(value='')))
# HBox(children=(HTML(value=''), FloatProgress(value=0.0, max=142.0), HTML(value='')))
# {'accuracy': 0.633, 'f1_pos': 0.522, 'f1_neu': 0.469, 'f1_neg': 0.748, 'eval_score': 0.544}
# {'max_length': 24, 'batch_size': 64}
#   5%|▌         | 1/20 [03:47<1:12:05, 227.65s/it, best loss: -0.544]
# Some weights of RobertaForSequenceClassification were not initialized from the model checkpoint at cardiffnlp/twitter-roberta-base-sentiment and are newly initialized: ['roberta.pooler.dense.weight', 'roberta.pooler.dense.bias']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# HBox(children=(HTML(value=''), FloatProgress(value=0.0, max=4517.0), HTML(value='')))
# HBox(children=(HTML(value='Epoch'), FloatProgress(value=0.0, max=2.0), HTML(value='')))
# HBox(children=(HTML(value='Running Epoch 0 of 2'), FloatProgress(value=0.0, max=71.0), HTML(value='')))
# HBox(children=(HTML(value='Running Epoch 1 of 2'), FloatProgress(value=0.0, max=71.0), HTML(value='')))
# HBox(children=(HTML(value=''), FloatProgress(value=0.0, max=1130.0), HTML(value='')))
# HBox(children=(HTML(value=''), FloatProgress(value=0.0, max=142.0), HTML(value='')))
# {'accuracy': 0.627, 'f1_pos': 0.513, 'f1_neu': 0.465, 'f1_neg': 0.737, 'eval_score': 0.536}
# {'max_length': 35, 'batch_size': 64}
#  10%|█         | 2/20 [06:34<1:02:49, 209.39s/it, best loss: -0.544]
# Some weights of RobertaForSequenceClassification were not initialized from the model checkpoint at cardiffnlp/twitter-roberta-base-sentiment and are newly initialized: ['roberta.pooler.dense.weight', 'roberta.pooler.dense.bias']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# HBox(children=(HTML(value=''), FloatProgress(value=0.0, max=4517.0), HTML(value='')))
# HBox(children=(HTML(value='Epoch'), FloatProgress(value=0.0, max=2.0), HTML(value='')))
# HBox(children=(HTML(value='Running Epoch 0 of 2'), FloatProgress(value=0.0, max=71.0), HTML(value='')))
# HBox(children=(HTML(value='Running Epoch 1 of 2'), FloatProgress(value=0.0, max=71.0), HTML(value='')))
# HBox(children=(HTML(value=''), FloatProgress(value=0.0, max=1130.0), HTML(value='')))
# HBox(children=(HTML(value=''), FloatProgress(value=0.0, max=142.0), HTML(value='')))
# {'accuracy': 0.604, 'f1_pos': 0.504, 'f1_neu': 0.43, 'f1_neg': 0.717, 'eval_score': 0.524}
# {'max_length': 14, 'batch_size': 16}
#  15%|█▌        | 3/20 [08:19<50:29, 178.18s/it, best loss: -0.544]
# Some weights of RobertaForSequenceClassification were not initialized from the model checkpoint at cardiffnlp/twitter-roberta-base-sentiment and are newly initialized: ['roberta.pooler.dense.weight', 'roberta.pooler.dense.bias']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# HBox(children=(HTML(value=''), FloatProgress(value=0.0, max=4517.0), HTML(value='')))
# HBox(children=(HTML(value='Epoch'), FloatProgress(value=0.0, max=2.0), HTML(value='')))
# HBox(children=(HTML(value='Running Epoch 0 of 2'), FloatProgress(value=0.0, max=283.0), HTML(value='')))
# HBox(children=(HTML(value='Running Epoch 1 of 2'), FloatProgress(value=0.0, max=283.0), HTML(value='')))
# HBox(children=(HTML(value=''), FloatProgress(value=0.0, max=1130.0), HTML(value='')))
# HBox(children=(HTML(value=''), FloatProgress(value=0.0, max=142.0), HTML(value='')))
# {'accuracy': 0.602, 'f1_pos': 0.524, 'f1_neu': 0.414, 'f1_neg': 0.716, 'eval_score': 0.54}
# {'max_length': 32, 'batch_size': 32}
#  20%|██        | 4/20 [10:25<43:20, 162.52s/it, best loss: -0.544]
# Some weights of RobertaForSequenceClassification were not initialized from the model checkpoint at cardiffnlp/twitter-roberta-base-sentiment and are newly initialized: ['roberta.pooler.dense.weight', 'roberta.pooler.dense.bias']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# HBox(children=(HTML(value=''), FloatProgress(value=0.0, max=4517.0), HTML(value='')))
# HBox(children=(HTML(value='Epoch'), FloatProgress(value=0.0, max=2.0), HTML(value='')))
# HBox(children=(HTML(value='Running Epoch 0 of 2'), FloatProgress(value=0.0, max=142.0), HTML(value='')))
# HBox(children=(HTML(value='Running Epoch 1 of 2'), FloatProgress(value=0.0, max=142.0), HTML(value='')))
# HBox(children=(HTML(value=''), FloatProgress(value=0.0, max=1130.0), HTML(value='')))
# HBox(children=(HTML(value=''), FloatProgress(value=0.0, max=142.0), HTML(value='')))
# {'accuracy': 0.633, 'f1_pos': 0.506, 'f1_neu': 0.464, 'f1_neg': 0.753, 'eval_score': 0.531}
# {'max_length': 47, 'batch_size': 32}
#  25%|██▌       | 5/20 [13:29<42:11, 168.79s/it, best loss: -0.544]
# Some weights of RobertaForSequenceClassification were not initialized from the model checkpoint at cardiffnlp/twitter-roberta-base-sentiment and are newly initialized: ['roberta.pooler.dense.weight', 'roberta.pooler.dense.bias']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# HBox(children=(HTML(value=''), FloatProgress(value=0.0, max=4517.0), HTML(value='')))
# HBox(children=(HTML(value='Epoch'), FloatProgress(value=0.0, max=2.0), HTML(value='')))
# HBox(children=(HTML(value='Running Epoch 0 of 2'), FloatProgress(value=0.0, max=142.0), HTML(value='')))
# HBox(children=(HTML(value='Running Epoch 1 of 2'), FloatProgress(value=0.0, max=142.0), HTML(value='')))
# HBox(children=(HTML(value=''), FloatProgress(value=0.0, max=1130.0), HTML(value='')))
# HBox(children=(HTML(value=''), FloatProgress(value=0.0, max=142.0), HTML(value='')))
# {'accuracy': 0.635, 'f1_pos': 0.513, 'f1_neu': 0.438, 'f1_neg': 0.751, 'eval_score': 0.537}
# {'max_length': 16, 'batch_size': 64}
#  30%|███       | 6/20 [15:16<35:06, 150.44s/it, best loss: -0.544]
# Some weights of RobertaForSequenceClassification were not initialized from the model checkpoint at cardiffnlp/twitter-roberta-base-sentiment and are newly initialized: ['roberta.pooler.dense.weight', 'roberta.pooler.dense.bias']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# HBox(children=(HTML(value=''), FloatProgress(value=0.0, max=4517.0), HTML(value='')))
# HBox(children=(HTML(value='Epoch'), FloatProgress(value=0.0, max=2.0), HTML(value='')))
# HBox(children=(HTML(value='Running Epoch 0 of 2'), FloatProgress(value=0.0, max=71.0), HTML(value='')))
# HBox(children=(HTML(value='Running Epoch 1 of 2'), FloatProgress(value=0.0, max=71.0), HTML(value='')))
# HBox(children=(HTML(value=''), FloatProgress(value=0.0, max=1130.0), HTML(value='')))
# HBox(children=(HTML(value=''), FloatProgress(value=0.0, max=142.0), HTML(value='')))
# {'accuracy': 0.61, 'f1_pos': 0.46, 'f1_neu': 0.452, 'f1_neg': 0.727, 'eval_score': 0.49}
# {'max_length': 54, 'batch_size': 64}
#  35%|███▌      | 7/20 [18:10<34:07, 157.52s/it, best loss: -0.544]
# Some weights of RobertaForSequenceClassification were not initialized from the model checkpoint at cardiffnlp/twitter-roberta-base-sentiment and are newly initialized: ['roberta.pooler.dense.weight', 'roberta.pooler.dense.bias']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# HBox(children=(HTML(value=''), FloatProgress(value=0.0, max=4517.0), HTML(value='')))
# HBox(children=(HTML(value='Epoch'), FloatProgress(value=0.0, max=2.0), HTML(value='')))
# HBox(children=(HTML(value='Running Epoch 0 of 2'), FloatProgress(value=0.0, max=71.0), HTML(value='')))
# HBox(children=(HTML(value='Running Epoch 1 of 2'), FloatProgress(value=0.0, max=71.0), HTML(value='')))
# HBox(children=(HTML(value=''), FloatProgress(value=0.0, max=1130.0), HTML(value='')))
# HBox(children=(HTML(value=''), FloatProgress(value=0.0, max=142.0), HTML(value='')))
# {'accuracy': 0.608, 'f1_pos': 0.454, 'f1_neu': 0.481, 'f1_neg': 0.719, 'eval_score': 0.485}
# {'max_length': 22, 'batch_size': 16}
#  40%|████      | 8/20 [20:01<28:42, 143.51s/it, best loss: -0.544]
# Some weights of RobertaForSequenceClassification were not initialized from the model checkpoint at cardiffnlp/twitter-roberta-base-sentiment and are newly initialized: ['roberta.pooler.dense.weight', 'roberta.pooler.dense.bias']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# HBox(children=(HTML(value=''), FloatProgress(value=0.0, max=4517.0), HTML(value='')))
# HBox(children=(HTML(value='Epoch'), FloatProgress(value=0.0, max=2.0), HTML(value='')))
# HBox(children=(HTML(value='Running Epoch 0 of 2'), FloatProgress(value=0.0, max=283.0), HTML(value='')))
# HBox(children=(HTML(value='Running Epoch 1 of 2'), FloatProgress(value=0.0, max=283.0), HTML(value='')))
# HBox(children=(HTML(value=''), FloatProgress(value=0.0, max=1130.0), HTML(value='')))
# HBox(children=(HTML(value=''), FloatProgress(value=0.0, max=142.0), HTML(value='')))
# {'accuracy': 0.619, 'f1_pos': 0.527, 'f1_neu': 0.463, 'f1_neg': 0.727, 'eval_score': 0.545}
# {'max_length': 7, 'batch_size': 16}
#  45%|████▌     | 9/20 [23:22<29:28, 160.73s/it, best loss: -0.545]
# Some weights of RobertaForSequenceClassification were not initialized from the model checkpoint at cardiffnlp/twitter-roberta-base-sentiment and are newly initialized: ['roberta.pooler.dense.weight', 'roberta.pooler.dense.bias']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# HBox(children=(HTML(value=''), FloatProgress(value=0.0, max=4517.0), HTML(value='')))
# HBox(children=(HTML(value='Epoch'), FloatProgress(value=0.0, max=2.0), HTML(value='')))
# HBox(children=(HTML(value='Running Epoch 0 of 2'), FloatProgress(value=0.0, max=283.0), HTML(value='')))
# HBox(children=(HTML(value='Running Epoch 1 of 2'), FloatProgress(value=0.0, max=283.0), HTML(value='')))
# HBox(children=(HTML(value=''), FloatProgress(value=0.0, max=1130.0), HTML(value='')))
# HBox(children=(HTML(value=''), FloatProgress(value=0.0, max=142.0), HTML(value='')))
# {'accuracy': 0.557, 'f1_pos': 0.364, 'f1_neu': 0.225, 'f1_neg': 0.695, 'eval_score': 0.403}
# {'max_length': 7, 'batch_size': 64}
#  50%|█████     | 10/20 [25:46<25:55, 155.56s/it, best loss: -0.545]
# Some weights of RobertaForSequenceClassification were not initialized from the model checkpoint at cardiffnlp/twitter-roberta-base-sentiment and are newly initialized: ['roberta.pooler.dense.weight', 'roberta.pooler.dense.bias']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# HBox(children=(HTML(value=''), FloatProgress(value=0.0, max=4517.0), HTML(value='')))
# HBox(children=(HTML(value='Epoch'), FloatProgress(value=0.0, max=2.0), HTML(value='')))
# HBox(children=(HTML(value='Running Epoch 0 of 2'), FloatProgress(value=0.0, max=71.0), HTML(value='')))
# HBox(children=(HTML(value='Running Epoch 1 of 2'), FloatProgress(value=0.0, max=71.0), HTML(value='')))
# HBox(children=(HTML(value=''), FloatProgress(value=0.0, max=1130.0), HTML(value='')))
# HBox(children=(HTML(value=''), FloatProgress(value=0.0, max=142.0), HTML(value='')))
# {'accuracy': 0.519, 'f1_pos': 0.0, 'f1_neu': 0.0, 'f1_neg': 0.684, 'eval_score': 0.104}
# {'max_length': 29, 'batch_size': 32}
#  55%|█████▌    | 11/20 [27:18<20:28, 136.48s/it, best loss: -0.545]
# Some weights of RobertaForSequenceClassification were not initialized from the model checkpoint at cardiffnlp/twitter-roberta-base-sentiment and are newly initialized: ['roberta.pooler.dense.weight', 'roberta.pooler.dense.bias']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# HBox(children=(HTML(value=''), FloatProgress(value=0.0, max=4517.0), HTML(value='')))
# HBox(children=(HTML(value='Epoch'), FloatProgress(value=0.0, max=2.0), HTML(value='')))
# HBox(children=(HTML(value='Running Epoch 0 of 2'), FloatProgress(value=0.0, max=142.0), HTML(value='')))
# HBox(children=(HTML(value='Running Epoch 1 of 2'), FloatProgress(value=0.0, max=142.0), HTML(value='')))
# HBox(children=(HTML(value=''), FloatProgress(value=0.0, max=1130.0), HTML(value='')))
# HBox(children=(HTML(value=''), FloatProgress(value=0.0, max=142.0), HTML(value='')))
# {'accuracy': 0.63, 'f1_pos': 0.526, 'f1_neu': 0.483, 'f1_neg': 0.736, 'eval_score': 0.547}
# {'max_length': 47, 'batch_size': 16}
#  60%|██████    | 12/20 [30:27<20:19, 152.49s/it, best loss: -0.547]
# Some weights of RobertaForSequenceClassification were not initialized from the model checkpoint at cardiffnlp/twitter-roberta-base-sentiment and are newly initialized: ['roberta.pooler.dense.weight', 'roberta.pooler.dense.bias']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# HBox(children=(HTML(value=''), FloatProgress(value=0.0, max=4517.0), HTML(value='')))
# HBox(children=(HTML(value='Epoch'), FloatProgress(value=0.0, max=2.0), HTML(value='')))
# HBox(children=(HTML(value='Running Epoch 0 of 2'), FloatProgress(value=0.0, max=283.0), HTML(value='')))
# HBox(children=(HTML(value='Running Epoch 1 of 2'), FloatProgress(value=0.0, max=283.0), HTML(value='')))
# HBox(children=(HTML(value=''), FloatProgress(value=0.0, max=1130.0), HTML(value='')))
# HBox(children=(HTML(value=''), FloatProgress(value=0.0, max=142.0), HTML(value='')))
# {'accuracy': 0.635, 'f1_pos': 0.531, 'f1_neu': 0.478, 'f1_neg': 0.742, 'eval_score': 0.552}
# {'max_length': 23, 'batch_size': 32}
#  65%|██████▌   | 13/20 [33:54<19:40, 168.65s/it, best loss: -0.552]
# Some weights of RobertaForSequenceClassification were not initialized from the model checkpoint at cardiffnlp/twitter-roberta-base-sentiment and are newly initialized: ['roberta.pooler.dense.weight', 'roberta.pooler.dense.bias']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# HBox(children=(HTML(value=''), FloatProgress(value=0.0, max=4517.0), HTML(value='')))
# HBox(children=(HTML(value='Epoch'), FloatProgress(value=0.0, max=2.0), HTML(value='')))
# HBox(children=(HTML(value='Running Epoch 0 of 2'), FloatProgress(value=0.0, max=142.0), HTML(value='')))
# HBox(children=(HTML(value='Running Epoch 1 of 2'), FloatProgress(value=0.0, max=142.0), HTML(value='')))
# HBox(children=(HTML(value=''), FloatProgress(value=0.0, max=1130.0), HTML(value='')))
# HBox(children=(HTML(value=''), FloatProgress(value=0.0, max=142.0), HTML(value='')))
# {'accuracy': 0.633, 'f1_pos': 0.514, 'f1_neu': 0.458, 'f1_neg': 0.747, 'eval_score': 0.538}
# {'max_length': 9, 'batch_size': 16}
#  70%|███████   | 14/20 [35:37<14:54, 149.02s/it, best loss: -0.552]
# Some weights of RobertaForSequenceClassification were not initialized from the model checkpoint at cardiffnlp/twitter-roberta-base-sentiment and are newly initialized: ['roberta.pooler.dense.weight', 'roberta.pooler.dense.bias']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# HBox(children=(HTML(value=''), FloatProgress(value=0.0, max=4517.0), HTML(value='')))
# HBox(children=(HTML(value='Epoch'), FloatProgress(value=0.0, max=2.0), HTML(value='')))
# HBox(children=(HTML(value='Running Epoch 0 of 2'), FloatProgress(value=0.0, max=283.0), HTML(value='')))
# HBox(children=(HTML(value='Running Epoch 1 of 2'), FloatProgress(value=0.0, max=283.0), HTML(value='')))
# HBox(children=(HTML(value=''), FloatProgress(value=0.0, max=1130.0), HTML(value='')))
# HBox(children=(HTML(value=''), FloatProgress(value=0.0, max=142.0), HTML(value='')))
# {'accuracy': 0.571, 'f1_pos': 0.425, 'f1_neu': 0.403, 'f1_neg': 0.692, 'eval_score': 0.454}
# {'max_length': 49, 'batch_size': 32}
#  75%|███████▌  | 15/20 [38:39<13:14, 158.86s/it, best loss: -0.552]
# Some weights of RobertaForSequenceClassification were not initialized from the model checkpoint at cardiffnlp/twitter-roberta-base-sentiment and are newly initialized: ['roberta.pooler.dense.weight', 'roberta.pooler.dense.bias']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# HBox(children=(HTML(value=''), FloatProgress(value=0.0, max=4517.0), HTML(value='')))
# HBox(children=(HTML(value='Epoch'), FloatProgress(value=0.0, max=2.0), HTML(value='')))
# HBox(children=(HTML(value='Running Epoch 0 of 2'), FloatProgress(value=0.0, max=142.0), HTML(value='')))
# HBox(children=(HTML(value='Running Epoch 1 of 2'), FloatProgress(value=0.0, max=142.0), HTML(value='')))
# HBox(children=(HTML(value=''), FloatProgress(value=0.0, max=1130.0), HTML(value='')))
# HBox(children=(HTML(value=''), FloatProgress(value=0.0, max=142.0), HTML(value='')))
# {'accuracy': 0.636, 'f1_pos': 0.531, 'f1_neu': 0.445, 'f1_neg': 0.748, 'eval_score': 0.552}
# {'max_length': 34, 'batch_size': 32}
#  80%|████████  | 16/20 [40:30<09:38, 144.67s/it, best loss: -0.552]
# Some weights of RobertaForSequenceClassification were not initialized from the model checkpoint at cardiffnlp/twitter-roberta-base-sentiment and are newly initialized: ['roberta.pooler.dense.weight', 'roberta.pooler.dense.bias']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# HBox(children=(HTML(value=''), FloatProgress(value=0.0, max=4517.0), HTML(value='')))
# Exception ignored in:
# <bound method _MultiProcessingDataLoaderIter.__del__ of <torch.utils.data.dataloader._MultiProcessingDataLoaderIter object at 0x7f96ef7d58d0>>
# Traceback (most recent call last):
#
#   File "/usr/local/lib/python3.6/dist-packages/torch/utils/data/dataloader.py", line 1203, in __del__
#
# self._shutdown_workers()
#   File "/usr/local/lib/python3.6/dist-packages/torch/utils/data/dataloader.py", line 1177, in _shutdown_workers
#
# w.join(timeout=_utils.MP_STATUS_CHECK_INTERVAL)
#   File "/usr/lib/python3.6/multiprocessing/process.py", line 122, in join
#
# assert self._parent_pid == os.getpid(), 'can only join a child process'
# AssertionError
# :
# can only join a child process
# Exception ignored in:
# <bound method _MultiProcessingDataLoaderIter.__del__ of <torch.utils.data.dataloader._MultiProcessingDataLoaderIter object at 0x7f96ed7f48d0>>
# Traceback (most recent call last):
#
#   File "/usr/local/lib/python3.6/dist-packages/torch/utils/data/dataloader.py", line 1203, in __del__
#
# self._shutdown_workers()
#   File "/usr/local/lib/python3.6/dist-packages/torch/utils/data/dataloader.py", line 1177, in _shutdown_workers
#
# w.join(timeout=_utils.MP_STATUS_CHECK_INTERVAL)
#   File "/usr/lib/python3.6/multiprocessing/process.py", line 122, in join
#
# assert self._parent_pid == os.getpid(), 'can only join a child process'
# AssertionError
# :
# can only join a child process
# HBox(children=(HTML(value='Epoch'), FloatProgress(value=0.0, max=2.0), HTML(value='')))
# HBox(children=(HTML(value='Running Epoch 0 of 2'), FloatProgress(value=0.0, max=142.0), HTML(value='')))
# HBox(children=(HTML(value='Running Epoch 1 of 2'), FloatProgress(value=0.0, max=142.0), HTML(value='')))
# HBox(children=(HTML(value=''), FloatProgress(value=0.0, max=1130.0), HTML(value='')))
# HBox(children=(HTML(value=''), FloatProgress(value=0.0, max=142.0), HTML(value='')))
# {'accuracy': 0.608, 'f1_pos': 0.491, 'f1_neu': 0.451, 'f1_neg': 0.722, 'eval_score': 0.514}
# {'max_length': 55, 'batch_size': 64}
#  85%|████████▌ | 17/20 [42:19<06:41, 133.95s/it, best loss: -0.552]
# Some weights of RobertaForSequenceClassification were not initialized from the model checkpoint at cardiffnlp/twitter-roberta-base-sentiment and are newly initialized: ['roberta.pooler.dense.weight', 'roberta.pooler.dense.bias']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# HBox(children=(HTML(value=''), FloatProgress(value=0.0, max=4517.0), HTML(value='')))
# HBox(children=(HTML(value='Epoch'), FloatProgress(value=0.0, max=2.0), HTML(value='')))
# HBox(children=(HTML(value='Running Epoch 0 of 2'), FloatProgress(value=0.0, max=71.0), HTML(value='')))
# HBox(children=(HTML(value='Running Epoch 1 of 2'), FloatProgress(value=0.0, max=71.0), HTML(value='')))
# HBox(children=(HTML(value=''), FloatProgress(value=0.0, max=1130.0), HTML(value='')))
# HBox(children=(HTML(value=''), FloatProgress(value=0.0, max=142.0), HTML(value='')))
# {'accuracy': 0.599, 'f1_pos': 0.391, 'f1_neu': 0.468, 'f1_neg': 0.724, 'eval_score': 0.433}
# {'max_length': 56, 'batch_size': 16}
#  90%|█████████ | 18/20 [45:13<04:51, 145.87s/it, best loss: -0.552]
# Some weights of RobertaForSequenceClassification were not initialized from the model checkpoint at cardiffnlp/twitter-roberta-base-sentiment and are newly initialized: ['roberta.pooler.dense.weight', 'roberta.pooler.dense.bias']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# HBox(children=(HTML(value=''), FloatProgress(value=0.0, max=4517.0), HTML(value='')))
# Exception ignored in:
# <bound method _MultiProcessingDataLoaderIter.__del__ of <torch.utils.data.dataloader._MultiProcessingDataLoaderIter object at 0x7f96eefdec50>>
# Traceback (most recent call last):
#
#   File "/usr/local/lib/python3.6/dist-packages/torch/utils/data/dataloader.py", line 1203, in __del__
#
# self._shutdown_workers()
#   File "/usr/local/lib/python3.6/dist-packages/torch/utils/data/dataloader.py", line 1177, in _shutdown_workers
#
# w.join(timeout=_utils.MP_STATUS_CHECK_INTERVAL)
#   File "/usr/lib/python3.6/multiprocessing/process.py", line 122, in join
#
# assert self._parent_pid == os.getpid(), 'can only join a child process'
# AssertionError
# :
# can only join a child process
# Exception ignored in:
# <bound method _MultiProcessingDataLoaderIter.__del__ of <torch.utils.data.dataloader._MultiProcessingDataLoaderIter object at 0x7f96ec0f8c50>>
# Traceback (most recent call last):
#
#   File "/usr/local/lib/python3.6/dist-packages/torch/utils/data/dataloader.py", line 1203, in __del__
#
# self._shutdown_workers()
#   File "/usr/local/lib/python3.6/dist-packages/torch/utils/data/dataloader.py", line 1177, in _shutdown_workers
#
# w.join(timeout=_utils.MP_STATUS_CHECK_INTERVAL)
#   File "/usr/lib/python3.6/multiprocessing/process.py", line 122, in join
#
# assert self._parent_pid == os.getpid(), 'can only join a child process'
# AssertionError
# :
# can only join a child process
# HBox(children=(HTML(value='Epoch'), FloatProgress(value=0.0, max=2.0), HTML(value='')))
# HBox(children=(HTML(value='Running Epoch 0 of 2'), FloatProgress(value=0.0, max=283.0), HTML(value='')))
# HBox(children=(HTML(value='Running Epoch 1 of 2'), FloatProgress(value=0.0, max=283.0), HTML(value='')))
# HBox(children=(HTML(value=''), FloatProgress(value=0.0, max=1130.0), HTML(value='')))
# HBox(children=(HTML(value=''), FloatProgress(value=0.0, max=142.0), HTML(value='')))
# {'accuracy': 0.633, 'f1_pos': 0.537, 'f1_neu': 0.461, 'f1_neg': 0.746, 'eval_score': 0.556}
# {'max_length': 29, 'batch_size': 32}
#  95%|█████████▌| 19/20 [48:40<02:44, 164.10s/it, best loss: -0.556]
# Some weights of RobertaForSequenceClassification were not initialized from the model checkpoint at cardiffnlp/twitter-roberta-base-sentiment and are newly initialized: ['roberta.pooler.dense.weight', 'roberta.pooler.dense.bias']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# HBox(children=(HTML(value=''), FloatProgress(value=0.0, max=4517.0), HTML(value='')))
# HBox(children=(HTML(value='Epoch'), FloatProgress(value=0.0, max=2.0), HTML(value='')))
# HBox(children=(HTML(value='Running Epoch 0 of 2'), FloatProgress(value=0.0, max=142.0), HTML(value='')))
# HBox(children=(HTML(value='Running Epoch 1 of 2'), FloatProgress(value=0.0, max=142.0), HTML(value='')))
# HBox(children=(HTML(value=''), FloatProgress(value=0.0, max=1130.0), HTML(value='')))
# HBox(children=(HTML(value=''), FloatProgress(value=0.0, max=142.0), HTML(value='')))
# {'accuracy': 0.627, 'f1_pos': 0.519, 'f1_neu': 0.454, 'f1_neg': 0.742, 'eval_score': 0.541}
# 100%|██████████| 20/20 [51:39<00:00, 154.96s/it, best loss: -0.556]
# {'batch_size': 0, 'max_length': 51}

# %%
{'max_length': 56, 'batch_size': 16}
{'accuracy': 0.633, 'f1_pos': 0.537, 'f1_neu': 0.461, 'f1_neg': 0.746, 'eval_score': 0.556}
# Out:
# {'accuracy': 0.622,
#  'eval_score': 0.547,
#  'f1_neg': 0.746,
#  'f1_neu': 0.377,
#  'f1_pos': 0.528}

# %%
'roberta-base'
{'max_length': 66, 'batch_size': 32}
{'accuracy': 0.622, 'f1_pos': 0.528, 'f1_neu': 0.377, 'f1_neg': 0.746, 'eval_score': 0.547}

# %%
print(adfadf)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-33-f592fdd2f7df> in <module>()
# ----> 1 print(adfadf)
#
# NameError: name 'adfadf' is not defined

# %%
model.train_model(train_pr_df)

# %%
def evaluation(labels, preds):

  f1_temp = np.round(f1_score(labels, preds, average=None),3)

  f1_Positive = f1_temp[0]
  f1_Neutral = f1_temp[1]
  f1_Negative = f1_temp[2]
  accuracy = round(accuracy_score(labels, preds),3) 
  eval_score = round(mean([accuracy, f1_Positive, f1_Negative]),3) 
  return eval_score

# %%
scores2, model_outputs, wrong_predictions = model.eval_model(val_pr_df, f1=evaluation, acc=accuracy_score, verbose  = False)

# %%
scores2

# %%
# y_pred  =  model.predict(val_pr_df['text'])[0]

# %%
# import logging
# from statistics import mean, mode

# import pandas as pd
# from sklearn.metrics import accuracy_score, f1_score
# from sklearn.model_selection import train_test_split

# import wandb
# from simpletransformers.classification import ClassificationArgs, ClassificationModel
# # from utils import load_rte_data_file

# sweep_config = {
#     "name": "vanilla-sweep-batch-16",
#     "method": "bayes",
#     "metric": {"name": "accuracy", "goal": "maximize"},
#     "parameters": {
#         "num_train_epochs": {"min": 1, "max": 20},
#         "learning_rate": {"min": 0, "max": 4e-4},
#     },
#     "early_terminate": {"type": "hyperband", "min_iter": 6,},
# }

# sweep_id = wandb.sweep(sweep_config, project="RTE - Hyperparameter Optimization")

# logging.basicConfig(level=logging.INFO)
# transformers_logger = logging.getLogger("transformers")
# transformers_logger.setLevel(logging.WARNING)

# # Preparing train data
# train_df = train_pr_df
# eval_df = val_pr_df

# model_args = ClassificationArgs()
# model_args.eval_batch_size = 8
# model_args.evaluate_during_training = True
# model_args.evaluate_during_training_silent = False
# model_args.evaluate_during_training_steps = 2
# model_args.learning_rate = 4e-4
# model_args.manual_seed = 4
# model_args.max_seq_length = 256
# model_args.multiprocessing_chunksize = 5000
# model_args.no_cache = True
# model_args.no_save = True
# model_args.num_train_epochs = 10
# model_args.overwrite_output_dir = True
# model_args.reprocess_input_data = True
# model_args.train_batch_size = 16
# model_args.gradient_accumulation_steps = 2
# model_args.train_custom_parameters_only = False
# model_args.labels_list = ["not_entailment", "entailment"]
# model_args.wandb_project = "RTE - Hyperparameter Optimization"


# def train():
#     # Initialize a new wandb run
#     wandb.init()

#     # Create a TransformerModel
#     model = ClassificationModel(
#         "roberta",
#         "roberta-large",
#         use_cuda=True,
#         args=model_args,
#         sweep_config=wandb.config,
#     )

#     # Train the model
#     model.train_model(
#         train_df,
#         eval_df=eval_df,
#         accuracy=lambda truth, predictions: accuracy_score(
#             truth, [round(p) for p in predictions]
#         ),
#     )

#     # Sync wandb
#     wandb.join()

# wandb.agent(sweep_id, train)

# %%
# import logging
# from statistics import mean, mode

# import pandas as pd
# from sklearn.metrics import accuracy_score, f1_score
# from sklearn.model_selection import train_test_split

# import wandb
# from simpletransformers.classification import ClassificationArgs, ClassificationModel
# # from utils import load_rte_data_file

# sweep_config = {
#     "name": "vanilla-sweep-batch-16",
#     "method": "bayes",
#     "metric": {"name": "accuracy", "goal": "maximize"},
#     "parameters": {
#         "num_train_epochs": {"min": 1, "max": 40},
#         "learning_rate": {"min": 0, "max": 4e-4},
#     },
#     "early_terminate": {"type": "hyperband", "min_iter": 6,},
# }

# sweep_id = wandb.sweep(sweep_config, project="RTE - Hyperparameter Optimization")

# logging.basicConfig(level=logging.INFO)
# transformers_logger = logging.getLogger("transformers")
# transformers_logger.setLevel(logging.WARNING)

# # Preparing train data
# train_df = train_pr_df
# eval_df = val_pr_df

# model_args = ClassificationArgs()
# model_args.eval_batch_size = 8
# model_args.evaluate_during_training = True
# model_args.evaluate_during_training_silent = False
# model_args.evaluate_during_training_steps = 1000
# model_args.learning_rate = 4e-4
# model_args.manual_seed = 4
# model_args.max_seq_length = 256
# model_args.multiprocessing_chunksize = 5000
# model_args.no_cache = True
# model_args.no_save = True
# model_args.num_train_epochs = 10
# model_args.overwrite_output_dir = True
# model_args.reprocess_input_data = True
# model_args.train_batch_size = 16
# model_args.gradient_accumulation_steps = 2
# model_args.train_custom_parameters_only = False
# model_args.labels_list = ["not_entailment", "entailment"]
# model_args.wandb_project = "RTE - Hyperparameter Optimization"


# def train():
#     # Initialize a new wandb run
#     wandb.init()

#     # Create a TransformerModel
#     model = ClassificationModel(
#         "roberta",
#         "roberta-large",
#         use_cuda=True,
#         args=model_args,
#         sweep_config=wandb.config,
#     )

#     # Train the model
#     model.train_model(
#         train_df,
#         eval_df=eval_df,
#         accuracy=lambda truth, predictions: accuracy_score(
#             truth, [round(p) for p in predictions]
#         ),
#     )

#     # Sync wandb
#     wandb.join()

# wandb.agent(sweep_id, train)
